# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
from sklearn.cluster import KMeans
import numpy as np
from sklearn import datasets, svm, metrics

# %%
data = pd.read_csv('dataset_group.csv')

# %%
X = np.array(data)

# %%
# If you use pandas for data handling, you can run this:
# por: Se você usa pandas para manipulação de dados, você pode executar isto:
import pandas as pd
df = pd.DataFrame(data)
df.replace([np.inf, -np.inf], np.nan)
df.info()

# The info() function will then tell you if you have any values that are non-computable.
# por: A função info () informará se você possui algum valor que não seja computável.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22342 entries, 0 to 22341
# Data columns (total 3 columns):
# 2000-01-01    22342 non-null object
# 1             22342 non-null int64
# yogurt        22342 non-null object
# dtypes: int64(1), object(2)
# memory usage: 523.7+ KB

# %%
data.head(10)
# Out:
#    2000-01-01  1         yogurt
# 0  2000-01-01  1           pork
# 1  2000-01-01  1  sandwich bags
# 2  2000-01-01  1     lunch meat
# 3  2000-01-01  1   all- purpose
# 4  2000-01-01  1          flour
# 5  2000-01-01  1           soda
# 6  2000-01-01  1         butter
# 7  2000-01-01  1     vegetables
# 8  2000-01-01  1           beef
# 9  2000-01-01  1  aluminum foil

# %%
data.fillna(0)
# Out:
#        2000-01-01     1                        yogurt
# 0      2000-01-01     1                          pork
# 1      2000-01-01     1                 sandwich bags
# 2      2000-01-01     1                    lunch meat
# 3      2000-01-01     1                  all- purpose
# 4      2000-01-01     1                         flour
# 5      2000-01-01     1                          soda
# 6      2000-01-01     1                        butter
# 7      2000-01-01     1                    vegetables
# 8      2000-01-01     1                          beef
# 9      2000-01-01     1                 aluminum foil
# 10     2000-01-01     1                  all- purpose
# 11     2000-01-01     1                  dinner rolls
# 12     2000-01-01     1                       shampoo
# 13     2000-01-01     1                  all- purpose
# 14     2000-01-01     1                         mixes
# 15     2000-01-01     1                          soap
# ...
